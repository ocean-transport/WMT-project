# %% [markdown]
# # Plotting SAM index
# try to plot like [Marshall's figs](https://climatedataguide.ucar.edu/climate-data/marshall-southern-annular-mode-sam-index-station-based)

# %%
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

# %%
ann_seas = pd.read_csv('ann-seas-sam-57-07.csv', delim_whitespace=True, parse_dates=True, )
mo = pd.read_csv('mo-sam-57-07.csv', delim_whitespace=True, parse_dates=True)

# %%
mo
# Out:
#              JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV  \
# 1957-01-01 -0.87 -2.27  0.07 -1.97 -2.50 -0.87  1.00 -1.73  0.72 -3.12 -5.42
# 1958-01-01  0.04 -2.84 -2.52 -0.30 -2.72 -0.97 -1.65  0.97  1.90 -0.16  0.30
# 1959-01-01  1.59 -0.19 -0.54 -1.25 -0.32 -1.12  0.18 -1.64  2.46 -0.46  3.28
# 1960-01-01  0.90  0.85  3.40 -0.35 -0.60 -0.17  0.31  0.43  1.41 -1.17  1.18
# 1961-01-01  0.91 -4.00 -0.40 -0.14  1.12 -0.40  0.98  1.10 -1.21  1.64  1.52
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2017-01-01 -1.12 -1.09 -1.56  1.65  1.82  1.98  0.16  0.31  0.42 -0.64  3.18
# 2018-01-01  2.72  1.02 -0.03 -1.66  0.01 -1.57  0.55 -0.78  1.83  2.76  2.84
# 2019-01-01  2.79 -1.87  1.47  0.86 -0.11  2.21 -2.20 -2.04  0.81 -1.97 -4.42
# 2020-01-01  0.57 -0.36  2.05 -1.72  1.03  1.18 -0.97 -2.20 -0.25  1.79  1.14
# 2021-01-01  1.95  2.19 -0.95  0.87  0.75  1.88 -1.06   NaN   NaN   NaN   NaN
#
#              DEC
# 1957-01-01 -2.63
# 1958-01-01  0.82
# 1959-01-01 -0.38
# 1960-01-01  1.36
# 1961-01-01  2.32
# ...          ...
# 2017-01-01  1.44
# 2018-01-01  1.44
# 2019-01-01 -1.78
# 2020-01-01  2.28
# 2021-01-01   NaN
#
# [65 rows x 12 columns]

# %%
mo.index = mo.index.rename('time')

# %%
mo
# Out:
#              JAN   FEB   MAR   APR   MAY   JUN   JUL   AUG   SEP   OCT   NOV  \
# time
# 1957-01-01 -0.87 -2.27  0.07 -1.97 -2.50 -0.87  1.00 -1.73  0.72 -3.12 -5.42
# 1958-01-01  0.04 -2.84 -2.52 -0.30 -2.72 -0.97 -1.65  0.97  1.90 -0.16  0.30
# 1959-01-01  1.59 -0.19 -0.54 -1.25 -0.32 -1.12  0.18 -1.64  2.46 -0.46  3.28
# 1960-01-01  0.90  0.85  3.40 -0.35 -0.60 -0.17  0.31  0.43  1.41 -1.17  1.18
# 1961-01-01  0.91 -4.00 -0.40 -0.14  1.12 -0.40  0.98  1.10 -1.21  1.64  1.52
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2017-01-01 -1.12 -1.09 -1.56  1.65  1.82  1.98  0.16  0.31  0.42 -0.64  3.18
# 2018-01-01  2.72  1.02 -0.03 -1.66  0.01 -1.57  0.55 -0.78  1.83  2.76  2.84
# 2019-01-01  2.79 -1.87  1.47  0.86 -0.11  2.21 -2.20 -2.04  0.81 -1.97 -4.42
# 2020-01-01  0.57 -0.36  2.05 -1.72  1.03  1.18 -0.97 -2.20 -0.25  1.79  1.14
# 2021-01-01  1.95  2.19 -0.95  0.87  0.75  1.88 -1.06   NaN   NaN   NaN   NaN
#
#              DEC
# time
# 1957-01-01 -2.63
# 1958-01-01  0.82
# 1959-01-01 -0.38
# 1960-01-01  1.36
# 1961-01-01  2.32
# ...          ...
# 2017-01-01  1.44
# 2018-01-01  1.44
# 2019-01-01 -1.78
# 2020-01-01  2.28
# 2021-01-01   NaN
#
# [65 rows x 12 columns]

# %%
#flattening dataframe by having next row go after the prev row, instead of col going after col
time = pd.date_range('1/1957', '1/2022', freq='M')
vector = np.array(mo.iloc[0])
for i in range(1,65):
    new_vec = np.array(mo.iloc[i])
    vector = np.append(vector,new_vec)

# %%
mo_xr = xr.DataArray(vector, coords=[time.rename('time')])

# %%
mo_xr.plot(figsize=(12,5));

# %%
plt.plot(time, vector);

# %%
mo_xr.where(mo_xr < 0).plot()

# %%
plt.figure(figsize=(12,5))
mo_xr.where(mo_xr < 0).plot(color='r')
mo_xr.where(mo_xr >= 0).plot(color='b')
plt.hlines(0, time[0], time[-1], colors='k')

# %%
fig = plt.figure(figsize=(12,5))
ax = plt.subplot(111)
ax.bar(time[np.where(vector<0)], mo_xr.where(mo_xr < 0).dropna(dim='time'), color='r', width=70)#, height=mo_xr.where(mo_xr < 0).values)
ax.bar(time[np.where(vector>=0)], mo_xr.where(mo_xr >= 0).dropna(dim='time'), color='b', width=70)#, height=mo_xr.where(mo_xr >= 0).values)
#ax.hlines(0, mo_xr.time[0], mo_xr.time[-1], colors='k', linewidth=0.5)
# Out:
# <BarContainer object of 408 artists>

# %%
fig = plt.figure(figsize=(12,5))
ax = plt.subplot(111)
ax.bar(time[np.where(vector<0)], mo_xr.where(mo_xr < 0).dropna(dim='time'), color='b', width=70)
ax.bar(time[np.where(vector>=0)], mo_xr.where(mo_xr >= 0).dropna(dim='time'), color='r', width=70)
ax.hlines(0, time[0], time[-1], colors='k', linewidth=0.8)
mo_xr.rolling(time=12).mean().plot(color='k', linewidth=1)
plt.title('Monthly data with annual rolling mean');

# %%
mo_xr.groupby('time.month').mean().plot()

# %%
mo.mean().plot()
# Out:
# <AxesSubplot:>

# %% [raw]
# mo_xr.rolling(time=12).mean()

# %%
mo_xr.rolling(time=)

# %%
fig, ax = plt.subplots(figsize=(12,5))
mo_xr.plot(ax=ax)
mo_xr.rolling(time=12).mean().plot();
